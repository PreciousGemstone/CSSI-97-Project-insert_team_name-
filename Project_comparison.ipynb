# %% [markdown]
# <a href="https://colab.research.google.com/github/PreciousGemstone/CSSI-97-Project-insert_team_name-/blob/main/Project_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Link to github our github with code for all models:
# https://github.com/PreciousGemstone/CSSI-97-Project-insert_team_name-

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn import linear_model
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
MSE_scores = {'Linear Regression': 161762.686067735, 'Decision Tree': 122993.84724677465, 'K Nearest Neighbours': 137826.19790495688, 'Random Forest(xgboost)': 87903.79202652822, 'Neural Network': 105038.62168418783}
MAE_scores = {'Linear Regression': 272.53769969876595, 'Decision Tree': 235.56622330121567, 'K Nearest Neighbours': 231.66314509803922, 'Random Forest(xgboost)': 196.72765663296568, 'Neural Network': 218.88821008527776}
r2_scores = {'Linear Regression': 0.7404710299305803, 'Decision Tree': 0.8026710159383427, 'K Nearest Neighbours': 0.7788742752708773, 'Random Forest(xgboost)': 0.8589688316606675, 'Neural Network': 0.8314780375754032}

# %%
models = ['Linear Regression','Decision Tree', 'K Nearest Neighbours', 'Random Forest(xgboost)', 'Neural Network']

fig, ax = plt.subplots(1, 3, figsize=(20, 6))

ax[0].bar(models, [MSE_scores['Linear Regression'], MSE_scores['Decision Tree'], MSE_scores['K Nearest Neighbours'], MSE_scores['Random Forest(xgboost)'], MSE_scores['Neural Network']])
ax[0].set_xlabel("Model Type", fontsize=12)
ax[0].set_ylabel("MSE Score", fontsize=12)
ax[0].set_title("MSE Scores Across Different Models")
ax[0].set_xticklabels(models, rotation=45, ha='right')
ax[0].grid(True, linestyle='--', linewidth=0.7,alpha = .4)

ax[1].bar(models, [MAE_scores['Linear Regression'], MAE_scores['Decision Tree'], MAE_scores['K Nearest Neighbours'], MAE_scores['Random Forest(xgboost)'], MAE_scores['Neural Network']])
ax[1].set_xlabel("Model Type", fontsize=12)
ax[1].set_ylabel("MAE Score($)", fontsize=12)
ax[1].set_title("MAE Scores Across Different Models")
ax[1].set_xticklabels(models, rotation=45, ha='right')
ax[1].grid(True, linestyle='--', linewidth=0.7,alpha = .4)

ax[2].bar(models, [r2_scores['Linear Regression'], r2_scores['Decision Tree'], r2_scores['K Nearest Neighbours'], r2_scores['Random Forest(xgboost)'], r2_scores['Neural Network']])
ax[2].set_xlabel("Model Type", fontsize=12)
ax[2].set_ylabel("r2 Score", fontsize=12)
ax[2].set_title("r2 Scores Across Different Models")
ax[2].set_xticklabels(models, rotation=45, ha='right')
ax[2].grid(True, linestyle='--', linewidth=0.7,alpha = .4)

plt.tight_layout()


plt.show()
# Out:
# /tmp/ipython-input-6-4217999553.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(models, rotation=45, ha='right')
# /tmp/ipython-input-6-4217999553.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(models, rotation=45, ha='right')
# /tmp/ipython-input-6-4217999553.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[2].set_xticklabels(models, rotation=45, ha='right')
